# %% [markdown]
# # Italy Covide Daywise

# %%
import pandas as pd

# %%
import numpy as np

# %%
covid_df=pd.read_csv('C:\\Users\\MOIN\\Italy covid daywise_panda\\covid19_italy_province.csv')

# %%
covid_df
# Out:
#          SNo                 Date Country  RegionCode RegionName  \
# 0          0  2020-02-24T18:00:00     ITA          13    Abruzzo
# 1          1  2020-02-24T18:00:00     ITA          13    Abruzzo
# 2          2  2020-02-24T18:00:00     ITA          13    Abruzzo
# 3          3  2020-02-24T18:00:00     ITA          13    Abruzzo
# 4          4  2020-02-24T18:00:00     ITA          13    Abruzzo
# ...      ...                  ...     ...         ...        ...
# 40196  40196  2020-12-06T17:00:00     ITA           5     Veneto
# 40197  40197  2020-12-06T17:00:00     ITA           5     Veneto
# 40198  40198  2020-12-06T17:00:00     ITA           5     Veneto
# 40199  40199  2020-12-06T17:00:00     ITA           5     Veneto
# 40200  40200  2020-12-06T17:00:00     ITA           5     Veneto
#
#        ProvinceCode                          ProvinceName  \
# 0                66                              L'Aquila
# 1                67                                Teramo
# ...

# %%
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40201 entries, 0 to 40200
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   SNo                   40201 non-null  int64
#  1   Date                  40201 non-null  object
#  2   Country               40201 non-null  object
#  3   RegionCode            40201 non-null  int64
#  4   RegionName            40201 non-null  object
#  5   ProvinceCode          40201 non-null  int64
#  6   ProvinceName          40201 non-null  object
#  7   ProvinceAbbreviation  30422 non-null  object
#  8   Latitude              30709 non-null  float64
#  9   Longitude             30709 non-null  float64
#  10  TotalPositiveCases    40201 non-null  int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 3.4+ MB

# %%
covid_df.describe()
# Out:
#                 SNo    RegionCode  ProvinceCode      Latitude     Longitude  \
# count  40201.000000  40201.000000  40201.000000  30709.000000  30709.000000
# mean   20100.000000     10.357354    266.261188     42.908522     12.096599
# std    11605.173423      5.993795    383.221679      2.631552      2.660590
# min        0.000000      1.000000      1.000000     36.925092      7.320149
# 25%    10050.000000      5.000000     36.000000     40.914047      9.828190
# 50%    20100.000000      9.000000     71.000000     43.715532     12.104734
# 75%    30150.000000     16.000000    110.000000     45.185093     14.167546
# max    40200.000000     22.000000    999.000000     46.499335     18.171897
#
#        TotalPositiveCases
# count        40201.000000
# mean          2563.579961
# std           6884.484083
# min              0.000000
# 25%            103.000000
# 50%            642.000000
# 75%           2605.000000
# max         158717.000000

# %%
covid_df.columns
# Out:
# Index(['SNo', 'Date', 'Country', 'RegionCode', 'RegionName', 'ProvinceCode',
#        'ProvinceName', 'ProvinceAbbreviation', 'Latitude', 'Longitude',
#        'TotalPositiveCases'],
#       dtype='object')

# %% [markdown]
# # Retrieving data from a data frame

# %% [markdown]
# The first thing you might want to do is to retrieve data from this data frame e.g. the counts of a specific day or the list of values in a specific column.Conceptually yiu can think of a dataframe as a dictionary of list the keys are column names,andvalues are list/arrays containing data for the respective columns

# %%
covid_df
# Out:
#          SNo                 Date Country  RegionCode RegionName  \
# 0          0  2020-02-24T18:00:00     ITA          13    Abruzzo
# 1          1  2020-02-24T18:00:00     ITA          13    Abruzzo
# 2          2  2020-02-24T18:00:00     ITA          13    Abruzzo
# 3          3  2020-02-24T18:00:00     ITA          13    Abruzzo
# 4          4  2020-02-24T18:00:00     ITA          13    Abruzzo
# ...      ...                  ...     ...         ...        ...
# 40196  40196  2020-12-06T17:00:00     ITA           5     Veneto
# 40197  40197  2020-12-06T17:00:00     ITA           5     Veneto
# 40198  40198  2020-12-06T17:00:00     ITA           5     Veneto
# 40199  40199  2020-12-06T17:00:00     ITA           5     Veneto
# 40200  40200  2020-12-06T17:00:00     ITA           5     Veneto
#
#        ProvinceCode                          ProvinceName  \
# 0                66                              L'Aquila
# 1                67                                Teramo
# ...

# %%
covid_df['ProvinceCode']
# Out:
# 0         66
# 1         67
# 2         68
# 3         69
# 4        979
#         ...
# 40196     27
# 40197     28
# 40198     29
# 40199    899
# 40200    999
# Name: ProvinceCode, Length: 40201, dtype: int64

# %%
type(covid_df['ProvinceCode'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# just like a arrays you can retrieve a specific value with a series using the indexing notation[ ]

# %%
covid_df['ProvinceCode'][40199]
# Out:
# 899

# %%
covid_df['ProvinceAbbreviation'][40197]
# Out:
# 'PD'

# %% [markdown]
# panda also provides the .at methode to directly retrieve at specific row and column

# %%
covid_df.at[40200,'RegionName']
# Out:
# 'Veneto'

# %%
covid_df.at[4,'Latitude']
# Out:
# nan

# %% [markdown]
# instead of using the indexing notation,pandas also allows accessing columns as properties of the data frame using the . notation.However this method only works for columns whose names do not conatain speces or special characters

# %%
covid_df.Latitude
# Out:
# 0        42.351222
# 1        42.658918
# 2        42.464584
# 3        42.351032
# 4              NaN
#            ...
# 40196    45.434905
# 40197    45.406930
# 40198    45.071073
# 40199          NaN
# 40200          NaN
# Name: Latitude, Length: 40201, dtype: float64

# %% [markdown]
# Further you can also pass a list of columns within the indexing notation to access a subset of the data frame with just the giving columns

# %%
Region_df=covid_df[['Longitude','TotalPositiveCases']]

# %%
Region_df
# Out:
#        Longitude  TotalPositiveCases
# 0      13.398438                   0
# 1      13.704400                   0
# 2      14.213648                   0
# 3      14.167546                   0
# 4            NaN                   0
# ...          ...                 ...
# 40196  12.338452               24142
# 40197  11.876087               31073
# 40198  11.790070                4577
# 40199        NaN                2809
# 40200        NaN                 403
#
# [40201 rows x 2 columns]

# %% [markdown]
# to access a specific row of data pandas provides the .loc methode

# %%
covid_df
# Out:
#          SNo                 Date Country  RegionCode RegionName  \
# 0          0  2020-02-24T18:00:00     ITA          13    Abruzzo
# 1          1  2020-02-24T18:00:00     ITA          13    Abruzzo
# 2          2  2020-02-24T18:00:00     ITA          13    Abruzzo
# 3          3  2020-02-24T18:00:00     ITA          13    Abruzzo
# 4          4  2020-02-24T18:00:00     ITA          13    Abruzzo
# ...      ...                  ...     ...         ...        ...
# 40196  40196  2020-12-06T17:00:00     ITA           5     Veneto
# 40197  40197  2020-12-06T17:00:00     ITA           5     Veneto
# 40198  40198  2020-12-06T17:00:00     ITA           5     Veneto
# 40199  40199  2020-12-06T17:00:00     ITA           5     Veneto
# 40200  40200  2020-12-06T17:00:00     ITA           5     Veneto
#
#        ProvinceCode                          ProvinceName  \
# 0                66                              L'Aquila
# 1                67                                Teramo
# ...

# %%
covid_df.loc[4]
# Out:
# SNo                                                        4
# Date                                     2020-02-24T18:00:00
# Country                                                  ITA
# RegionCode                                                13
# RegionName                                           Abruzzo
# ProvinceCode                                             979
# ProvinceName            In fase di definizione/aggiornamento
# ProvinceAbbreviation                                     NaN
# Latitude                                                 NaN
# Longitude                                                NaN
# TotalPositiveCases                                         0
# Name: 4, dtype: object

# %% [markdown]
# To view the first or last few rows of data we can use the .head and .tail methods

# %%
covid_df.head(5)
# Out:
#    SNo                 Date Country  RegionCode RegionName  ProvinceCode  \
# 0    0  2020-02-24T18:00:00     ITA          13    Abruzzo            66
# 1    1  2020-02-24T18:00:00     ITA          13    Abruzzo            67
# 2    2  2020-02-24T18:00:00     ITA          13    Abruzzo            68
# 3    3  2020-02-24T18:00:00     ITA          13    Abruzzo            69
# 4    4  2020-02-24T18:00:00     ITA          13    Abruzzo           979
#
#                            ProvinceName ProvinceAbbreviation   Latitude  \
# 0                              L'Aquila                   AQ  42.351222
# 1                                Teramo                   TE  42.658918
# 2                               Pescara                   PE  42.464584
# 3                                Chieti                   CH  42.351032
# 4  In fase di definizione/aggiornamento                  NaN        NaN
#
#    Longitude  TotalPositiveCases
# 0  13.398438                   0
# ...

# %%
covid_df.tail(6)
# Out:
#          SNo                 Date Country  RegionCode RegionName  \
# 40195  40195  2020-12-06T17:00:00     ITA           5     Veneto
# 40196  40196  2020-12-06T17:00:00     ITA           5     Veneto
# 40197  40197  2020-12-06T17:00:00     ITA           5     Veneto
# 40198  40198  2020-12-06T17:00:00     ITA           5     Veneto
# 40199  40199  2020-12-06T17:00:00     ITA           5     Veneto
# 40200  40200  2020-12-06T17:00:00     ITA           5     Veneto
#
#        ProvinceCode                          ProvinceName  \
# 40195            26                               Treviso
# 40196            27                               Venezia
# 40197            28                                Padova
# 40198            29                                Rovigo
# 40199           899    Fuori Regione / Provincia Autonoma
# 40200           999  In fase di definizione/aggiornamento
#
#       ProvinceAbbreviation   Latitude  Longitude  TotalPositiveCases
# ...

# %%
covid_df.at[0,'ProvinceName']
# Out:
# "L'Aquila"

# %%
type(covid_df.at[0,'ProvinceName'])
# Out:
# str

# %% [markdown]
# Lets look at few rows before and after this index to verify that the values indeed change from nan to actual numbers we can do this by passing a range to loc

# %%
covid_df.loc[40196:40200]
# Out:
#          SNo                 Date Country  RegionCode RegionName  \
# 40196  40196  2020-12-06T17:00:00     ITA           5     Veneto
# 40197  40197  2020-12-06T17:00:00     ITA           5     Veneto
# 40198  40198  2020-12-06T17:00:00     ITA           5     Veneto
# 40199  40199  2020-12-06T17:00:00     ITA           5     Veneto
# 40200  40200  2020-12-06T17:00:00     ITA           5     Veneto
#
#        ProvinceCode                          ProvinceName  \
# 40196            27                               Venezia
# 40197            28                                Padova
# 40198            29                                Rovigo
# 40199           899    Fuori Regione / Provincia Autonoma
# 40200           999  In fase di definizione/aggiornamento
#
#       ProvinceAbbreviation   Latitude  Longitude  TotalPositiveCases
# 40196                   VE  45.434905  12.338452               24142
# 40197                   PD  45.406930  11.876087               31073
# ...

# %% [markdown]
# The .sample methode can be used to retrieve a random sample of rows the data frame

# %%
covid_df.sample(12)
# Out:
#          SNo                 Date Country  RegionCode     RegionName  \
# 443      443  2020-02-27T18:00:00     ITA          11         Marche
# 40074  40074  2020-12-06T17:00:00     ITA          15       Campania
# 36541  36541  2020-11-12T17:00:00     ITA           3      Lombardia
# 17108  17108  2020-07-05T17:00:00     ITA          13        Abruzzo
# 21292  21292  2020-08-02T17:00:00     ITA          18       Calabria
# 19180  19180  2020-07-18T17:00:00     ITA           2  Valle d'Aosta
# 17325  17325  2020-07-06T17:00:00     ITA          11         Marche
# 34611  34611  2020-10-30T17:00:00     ITA          11         Marche
# 32796  32796  2020-10-18T17:00:00     ITA          12          Lazio
# 4181    4181  2020-03-27T17:00:00     ITA          16         Puglia
# 11898  11898  2020-05-26T17:00:00     ITA           5         Veneto
# 1165    1165  2020-03-04T17:00:00     ITA          18       Calabria
#
#        ProvinceCode                          ProvinceName  \
# ...

# %% [markdown]
# # Analyzing Data from data frames

# %%
total_cases=covid_df.TotalPositiveCases.sum()

# %%
print(total_cases)
# Out:
# 103058478

# %% [markdown]
# # Querying and sorting rows

# %%
high_positive_cases=covid_df.TotalPositiveCases > 1000
high_positive_cases
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 40196     True
# 40197     True
# 40198     True
# 40199     True
# 40200    False
# Name: TotalPositiveCases, Length: 40201, dtype: bool

# %%
covid_df[high_positive_cases]
# Out:
#          SNo                 Date Country  RegionCode RegionName  \
# 1842    1842  2020-03-09T18:00:00     ITA           3  Lombardia
# 1970    1970  2020-03-10T18:00:00     ITA           3  Lombardia
# 2098    2098  2020-03-11T17:00:00     ITA           3  Lombardia
# 2099    2099  2020-03-11T17:00:00     ITA           3  Lombardia
# 2101    2101  2020-03-11T17:00:00     ITA           3  Lombardia
# ...      ...                  ...     ...         ...        ...
# 40195  40195  2020-12-06T17:00:00     ITA           5     Veneto
# 40196  40196  2020-12-06T17:00:00     ITA           5     Veneto
# 40197  40197  2020-12-06T17:00:00     ITA           5     Veneto
# 40198  40198  2020-12-06T17:00:00     ITA           5     Veneto
# 40199  40199  2020-12-06T17:00:00     ITA           5     Veneto
#
#        ProvinceCode                        ProvinceName ProvinceAbbreviation  \
# 1842             16                             Bergamo                   BG
# ...

# %% [markdown]
# # Sorting rows using column values

# %%
covid_df.sort_values('TotalPositiveCases', ascending=False).head(10)
# Out:
#          SNo                 Date Country  RegionCode RegionName  \
# 40109  40109  2020-12-06T17:00:00     ITA           3  Lombardia
# 39960  39960  2020-12-05T17:00:00     ITA           3  Lombardia
# 39811  39811  2020-12-04T17:00:00     ITA           3  Lombardia
# 39662  39662  2020-12-03T17:00:00     ITA           3  Lombardia
# 39513  39513  2020-12-02T17:00:00     ITA           3  Lombardia
# 39364  39364  2020-12-01T17:00:00     ITA           3  Lombardia
# 39215  39215  2020-11-30T17:00:00     ITA           3  Lombardia
# 39066  39066  2020-11-29T17:00:00     ITA           3  Lombardia
# 38917  38917  2020-11-28T17:00:00     ITA           3  Lombardia
# 38768  38768  2020-11-27T17:00:00     ITA           3  Lombardia
#
#        ProvinceCode ProvinceName ProvinceAbbreviation   Latitude  Longitude  \
# 40109            15       Milano                   MI  45.466794   9.190347
# 39960            15       Milano                   MI  45.466794   9.190347
# ...

# %% [markdown]
# # Working with dates

# %%
covid_df.Date
# Out:
# 0        2020-02-24T18:00:00
# 1        2020-02-24T18:00:00
# 2        2020-02-24T18:00:00
# 3        2020-02-24T18:00:00
# 4        2020-02-24T18:00:00
#                 ...
# 40196    2020-12-06T17:00:00
# 40197    2020-12-06T17:00:00
# 40198    2020-12-06T17:00:00
# 40199    2020-12-06T17:00:00
# 40200    2020-12-06T17:00:00
# Name: Date, Length: 40201, dtype: object

# %%
covid_df['Date']=pd.to_datetime(covid_df.Date)

# %%
covid_df['Date']
# Out:
# 0       2020-02-24 18:00:00
# 1       2020-02-24 18:00:00
# 2       2020-02-24 18:00:00
# 3       2020-02-24 18:00:00
# 4       2020-02-24 18:00:00
#                 ...
# 40196   2020-12-06 17:00:00
# 40197   2020-12-06 17:00:00
# 40198   2020-12-06 17:00:00
# 40199   2020-12-06 17:00:00
# 40200   2020-12-06 17:00:00
# Name: Date, Length: 40201, dtype: datetime64[ns]

# %%
covid_df['year']= pd.DatetimeIndex(covid_df.Date).year
covid_df['month']= pd.DatetimeIndex(covid_df.Date).month
covid_df['day']= pd.DatetimeIndex(covid_df.Date).day
covid_df['weekday']= pd.DatetimeIndex(covid_df.Date).weekday
covid_df
# Out:
#          SNo                Date Country  RegionCode RegionName  ProvinceCode  \
# 0          0 2020-02-24 18:00:00     ITA          13    Abruzzo            66
# 1          1 2020-02-24 18:00:00     ITA          13    Abruzzo            67
# 2          2 2020-02-24 18:00:00     ITA          13    Abruzzo            68
# 3          3 2020-02-24 18:00:00     ITA          13    Abruzzo            69
# 4          4 2020-02-24 18:00:00     ITA          13    Abruzzo           979
# ...      ...                 ...     ...         ...        ...           ...
# 40196  40196 2020-12-06 17:00:00     ITA           5     Veneto            27
# 40197  40197 2020-12-06 17:00:00     ITA           5     Veneto            28
# 40198  40198 2020-12-06 17:00:00     ITA           5     Veneto            29
# 40199  40199 2020-12-06 17:00:00     ITA           5     Veneto           899
# 40200  40200 2020-12-06 17:00:00     ITA           5     Veneto           999
#
# ...

# %%
covid_df_december_metrics=covid_df_december[['Country','RegionCode','RegionName']]
covid_df_december_metrics
# Out:
#       Country  RegionCode RegionName
# 39307     ITA          13    Abruzzo
# 39308     ITA          13    Abruzzo
# 39309     ITA          13    Abruzzo
# 39310     ITA          13    Abruzzo
# 39311     ITA          13    Abruzzo
# ...       ...         ...        ...
# 40196     ITA           5     Veneto
# 40197     ITA           5     Veneto
# 40198     ITA           5     Veneto
# 40199     ITA           5     Veneto
# 40200     ITA           5     Veneto
#
# [894 rows x 3 columns]

# %%
covid_december_totals= covid_df_december_metrics.sum()
covid_december_totals
# Out:
# Country       ITAITAITAITAITAITAITAITAITAITAITAITAITAITAITAI...
# RegionCode                                                 9072
# RegionName    AbruzzoAbruzzoAbruzzoAbruzzoAbruzzoAbruzzoBasi...
# dtype: object

# %%
#Overall average
covid_df.TotalPositiveCases.mean()
# Out:
# 2563.579960697495

# %%
#Average for sundays
covid_df[covid_df.weekday==6].TotalPositiveCases.mean()
# Out:
# 2697.5731919332407

# %%
covid_df[covid_df.weekday==5].TotalPositiveCases.mean()
# Out:
# 2653.932371349096

# %%
covid_df[covid_df.weekday==4].TotalPositiveCases.mean()
# Out:
# 2605.189325452017

# %% [markdown]
# # Grouping and aggregation

# %% [markdown]
# As a next step we might want to summarize te daywise data and create a new dataframe with month-wise data.This is where the groupby function is useful.Along with a grouping we need to specify a way to aggregate the data for each group

# %%
covid_df
# Out:
#          SNo                Date Country  RegionCode RegionName  ProvinceCode  \
# 0          0 2020-02-24 18:00:00     ITA          13    Abruzzo            66
# 1          1 2020-02-24 18:00:00     ITA          13    Abruzzo            67
# 2          2 2020-02-24 18:00:00     ITA          13    Abruzzo            68
# 3          3 2020-02-24 18:00:00     ITA          13    Abruzzo            69
# 4          4 2020-02-24 18:00:00     ITA          13    Abruzzo           979
# ...      ...                 ...     ...         ...        ...           ...
# 40196  40196 2020-12-06 17:00:00     ITA           5     Veneto            27
# 40197  40197 2020-12-06 17:00:00     ITA           5     Veneto            28
# 40198  40198 2020-12-06 17:00:00     ITA           5     Veneto            29
# 40199  40199 2020-12-06 17:00:00     ITA           5     Veneto           899
# 40200  40200 2020-12-06 17:00:00     ITA           5     Veneto           999
#
# ...

# %%
monthly_groups= covid_df.groupby('month')

# %% [markdown]
# # Basic Plotting with Pandas

# %% [markdown]
# While we typicaly use a library like matplotlib or seaborn plot graphs with jupyter notebook pandas data frames and series also provide a handy .plot method for quick andeasy plotting
# Lets plot line graph showing how the no of daily cases varies over time using the plot method of a pandas series

# %%
covid_df
# Out:
#          SNo                Date Country  RegionCode RegionName  ProvinceCode  \
# 0          0 2020-02-24 18:00:00     ITA          13    Abruzzo            66
# 1          1 2020-02-24 18:00:00     ITA          13    Abruzzo            67
# 2          2 2020-02-24 18:00:00     ITA          13    Abruzzo            68
# 3          3 2020-02-24 18:00:00     ITA          13    Abruzzo            69
# 4          4 2020-02-24 18:00:00     ITA          13    Abruzzo           979
# ...      ...                 ...     ...         ...        ...           ...
# 40196  40196 2020-12-06 17:00:00     ITA           5     Veneto            27
# 40197  40197 2020-12-06 17:00:00     ITA           5     Veneto            28
# 40198  40198 2020-12-06 17:00:00     ITA           5     Veneto            29
# 40199  40199 2020-12-06 17:00:00     ITA           5     Veneto           899
# 40200  40200 2020-12-06 17:00:00     ITA           5     Veneto           999
#
# ...

# %%
covid_df.TotalPositiveCases.plot()
# Out:
# <AxesSubplot:>

# %%
covid_df.set_index('Date', inplace=True)

# %%
covid_df
# Out:
#                        SNo Country  RegionCode RegionName  ProvinceCode  \
# Date
# 2020-02-24 18:00:00      0     ITA          13    Abruzzo            66
# 2020-02-24 18:00:00      1     ITA          13    Abruzzo            67
# 2020-02-24 18:00:00      2     ITA          13    Abruzzo            68
# 2020-02-24 18:00:00      3     ITA          13    Abruzzo            69
# 2020-02-24 18:00:00      4     ITA          13    Abruzzo           979
# ...                    ...     ...         ...        ...           ...
# 2020-12-06 17:00:00  40196     ITA           5     Veneto            27
# 2020-12-06 17:00:00  40197     ITA           5     Veneto            28
# 2020-12-06 17:00:00  40198     ITA           5     Veneto            29
# 2020-12-06 17:00:00  40199     ITA           5     Veneto           899
# 2020-12-06 17:00:00  40200     ITA           5     Veneto           999
#
#                                              ProvinceName  \
# Date
# ...

# %%
covid_df.loc['2020-02-24']
# Out:
#                      SNo Country  RegionCode RegionName  ProvinceCode  \
# Date
# 2020-02-24 18:00:00    0     ITA          13    Abruzzo            66
# 2020-02-24 18:00:00    1     ITA          13    Abruzzo            67
# 2020-02-24 18:00:00    2     ITA          13    Abruzzo            68
# 2020-02-24 18:00:00    3     ITA          13    Abruzzo            69
# 2020-02-24 18:00:00    4     ITA          13    Abruzzo           979
# ...                  ...     ...         ...        ...           ...
# 2020-02-24 18:00:00  123     ITA           5     Veneto            26
# 2020-02-24 18:00:00  124     ITA           5     Veneto            27
# 2020-02-24 18:00:00  125     ITA           5     Veneto            28
# 2020-02-24 18:00:00  126     ITA           5     Veneto            29
# 2020-02-24 18:00:00  127     ITA           5     Veneto           999
#
#                                              ProvinceName  \
# Date
# ...

# %%
covid_df.TotalPositiveCases.plot()
covid_df.Latitude.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
covid_df.TotalPositiveCases.plot()
covid_df.Latitude.plot()
covid_df.Longitude.plot()
# Out:
# <AxesSubplot:xlabel='Date'>
